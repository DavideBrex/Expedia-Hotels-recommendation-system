# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path="C:\\Users\\Dennis\\Documents\\Bioinformatics\\Data_mining\\Data_mining_assignment_2\\"
sb_samples = pd.read_csv(path+"/training_set_VU_DM.csv",nrows=100000)
sb_samples.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score  ...  comp6_rate_percent_diff  \
# 0                3                3.5  ...                      NaN
# 1                4                4.0  ...                      NaN
# 2                3                4.5  ...                      NaN
# 3                2                4.0  ...                      NaN
# 4                4                3.5  ...                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff  click_bool  gross_bookings_usd  booking_bool
# 0                      NaN           0                 NaN             0
# 1                      NaN           0                 NaN             0
# 2                      NaN           0                 NaN             0
# 3                      5.0           0                 NaN             0
# 4                      NaN           0                 NaN             0
#
# [5 rows x 54 columns]

# %%
sb_samples_f = sb_samples
sb_samples_f["starrating_diff"] = abs(sb_samples_f["visitor_hist_starrating"] - sb_samples_f["prop_starrating"])
sb_samples_f["usd_diff"] = abs(np.log10(sb_samples_f["visitor_hist_adr_usd"]) - np.log10(sb_samples_f["price_usd"]))
sb_samples_f = sb_samples_f.fillna(value = {"starrating_diff": 6, "usd_diff": 1.1})
sb_samples_f.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score  ...  comp7_inv  \
# 0                3                3.5  ...        NaN
# 1                4                4.0  ...        NaN
# 2                3                4.5  ...        NaN
# 3                2                4.0  ...        NaN
# 4                4                3.5  ...        NaN
#
#    comp7_rate_percent_diff  comp8_rate  comp8_inv  comp8_rate_percent_diff  \
# 0                      NaN         0.0        0.0                      NaN
# 1                      NaN         0.0        0.0                      NaN
# 2                      NaN         0.0        0.0                      NaN
# 3                      NaN        -1.0        0.0                      5.0
# 4                      NaN         0.0        0.0                      NaN
#
#    click_bool  gross_bookings_usd  booking_bool  starrating_diff  usd_diff
# 0           0                 NaN             0              6.0       1.1
# 1           0                 NaN             0              6.0       1.1
# 2           0                 NaN             0              6.0       1.1
# 3           0                 NaN             0              6.0       1.1
# 4           0                 NaN             0              6.0       1.1
#
# [5 rows x 56 columns]

# %%
plt.hist(sb_samples_f.loc[sb_samples_f.booking_bool == 1][:]["starrating_diff"], bins = range(0,7))
plt.xlabel("starrating difference (abs)")
plt.ylabel("number of bookings")
plt.title("Starrating difference in booked hotels")
plt.show()

# %%
plt.hist(sb_samples_f.loc[sb_samples_f.click_bool == 1][:]["starrating_diff"], bins = range(0,7))
plt.xlabel("starrating difference (abs)")
plt.ylabel("number of bookings")
plt.title("Starrating difference in booked hotels")
plt.show()

# %%
plt.hist(sb_samples_f.loc[sb_samples_f.booking_bool == 1][:]["usd_diff"], bins = np.arange(0,1.2,0.1))
plt.xlabel("Log10 price difference (abs)")
plt.ylabel("number of bookings")
plt.title("Price difference in booked hotels")
plt.show()

# %%
plt.hist(sb_samples_f.loc[sb_samples_f.click_bool == 1][:]["usd_diff"], bins = np.arange(0,1.2,0.1))
plt.xlabel("Log10 price difference (abs)")
plt.ylabel("number of bookings")
plt.title("Price difference in booked hotels")
plt.show()
