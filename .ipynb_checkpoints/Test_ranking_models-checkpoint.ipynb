# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score
import pandas as pd
import numpy as np

# %%
path="C://Users//david\Desktop//VU amsterdam//Data mining"
train = pd.read_csv(path+"/Feature_engineering_train.csv")
train.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  srch_id            date_time  \
# 0           0             0               0       43  2013-01-09 16:45:45
# 1           1             1               1       43  2013-01-09 16:45:45
# 2           2             2               2       43  2013-01-09 16:45:45
# 3           3             3               3       43  2013-01-09 16:45:45
# 4           4             4               4       43  2013-01-09 16:45:45
#
#    site_id  visitor_location_country_id  visitor_hist_starrating  \
# 0        5                          219                      NaN
# 1        5                          219                      NaN
# 2        5                          219                      NaN
# 3        5                          219                      NaN
# 4        5                          219                      NaN
#
#    visitor_hist_adr_usd  prop_country_id      ...        \
# 0                   NaN              219      ...
# 1                   NaN              219      ...
# 2                   NaN              219      ...
# 3                   NaN              219      ...
# 4                   NaN              219      ...
#
#    srch_query_affinity_score  random_bool  click_bool  gross_bookings_usd  \
# 0                  -326.5675            1           0                 NaN
# 1                  -326.5675            1           0                 NaN
# 2                  -326.5675            1           0                 NaN
# 3                  -326.5675            1           0                 NaN
# 4                  -326.5675            1           0                 NaN
#
#    booking_bool  starrating_diff  usd_diff  booked_percentage  \
# 0             0              6.0       1.1           0.000000
# 1             0              6.0       1.1           0.000000
# 2             0              6.0       1.1           0.000000
# 3             0              6.0       1.1           0.000000
# 4             0              6.0       1.1           3.488372
#
#    clicked_percentage  avg_comp_rate
# 0            1.075269           0.00
# 1            0.680272           1.00
# 2            0.000000           0.00
# 3            0.000000           0.00
# 4            5.813953           0.75
#
# [5 rows x 37 columns]

# %%
train= train.drop(["Unnamed: 0","Unnamed: 0.1","Unnamed: 0.1.1"],axis=1)
train
# Out:
#          srch_id            date_time  site_id  visitor_location_country_id  \
# 0             43  2013-01-09 16:45:45        5                          219
# 1             43  2013-01-09 16:45:45        5                          219
# 2             43  2013-01-09 16:45:45        5                          219
# 3             43  2013-01-09 16:45:45        5                          219
# 4             43  2013-01-09 16:45:45        5                          219
# 5             43  2013-01-09 16:45:45        5                          219
# 6             43  2013-01-09 16:45:45        5                          219
# 7             43  2013-01-09 16:45:45        5                          219
# 8             43  2013-01-09 16:45:45        5                          219
# 9             43  2013-01-09 16:45:45        5                          219
# 10            43  2013-01-09 16:45:45        5                          219
# 11            43  2013-01-09 16:45:45        5                          219
# 12            43  2013-01-09 16:45:45        5                          219
# 13            43  2013-01-09 16:45:45        5                          219
# 14            43  2013-01-09 16:45:45        5                          219
# 15            43  2013-01-09 16:45:45        5                          219
# 16            43  2013-01-09 16:45:45        5                          219
# 17            43  2013-01-09 16:45:45        5                          219
# 18            43  2013-01-09 16:45:45        5                          219
# 19            43  2013-01-09 16:45:45        5                          219
# 20            43  2013-01-09 16:45:45        5                          219
# 21            43  2013-01-09 16:45:45        5                          219
# 22            43  2013-01-09 16:45:45        5                          219
# 23            43  2013-01-09 16:45:45        5                          219
# 24            43  2013-01-09 16:45:45        5                          219
# 25            43  2013-01-09 16:45:45        5                          219
# 26            43  2013-01-09 16:45:45        5                          219
# 27            43  2013-01-09 16:45:45        5                          219
# 1477876                      NaN                   NaN               45
# 1477877                      NaN                   NaN               45
# 1477878                      NaN                   NaN               45
# 1477879                      NaN                   NaN               45
# 1477880                      NaN                   NaN               45
# 1477881                      NaN                   NaN              117
# 1477882                      NaN                   NaN              117
# 1477883                      NaN                   NaN              117
# 1477884                      NaN                   NaN              117
# 1477885                      NaN                   NaN              117
# 1477886                      NaN                   NaN              117
# 1477887                      NaN                   NaN              117
# 1477888                      NaN                   NaN              117
# 1477889                      NaN                   NaN              117
# 1477890                      NaN                   NaN              117
# 1477891                      NaN                   NaN              117
# 1477892                      NaN                   NaN              117
# 1477893                      NaN                   NaN              117
# 1477894                      NaN                   NaN              117
# 1477895                      NaN                   NaN              117
# 1477896                      NaN                   NaN              117
# 1477897                      NaN                   NaN              117
# 1477898                      NaN                   NaN              117
#
#          prop_id  prop_starrating  prop_review_score      ...        \
# 0           7011                2                2.0      ...
# 1           8797                2                2.5      ...
# 2          14530                3                5.0      ...
# 3          15770                2                2.5      ...
# 4          20295                3                4.0      ...
# 5          22013                3                3.5      ...
# 6          25236                4                3.0      ...
# 7          27142                4                4.0      ...
# 8          31166                2                3.0      ...
# 9          31486                4                4.0      ...
# 10         37124                4                4.0      ...
# 11         37304                2                3.5      ...
# 12         37543                4                3.5      ...
# 13         42011                3                3.0      ...
# 14         43657                4                4.0      ...
# 15         48375                4                3.5      ...
# 16         55050                2                3.5      ...
# 17         59322                3                3.5      ...
# 18         62237                2                3.5      ...
# 19         68833                2                3.5      ...
# 20         72189                2                3.5      ...
# 21         77411                1                3.0      ...
# 22         79235                2                3.0      ...
# 23         79537                4                4.0      ...
# 24         85321                3                4.5      ...
# 25         88316                2                3.5      ...
# 26         90836                2                2.5      ...
# 27         95182                4                4.0      ...
# 28        102874                4                4.0      ...
# 29        103197                2                3.0      ...
# ...          ...              ...                ...      ...
# 1477869    76828                4                4.5      ...
# 1477870    85443                3                4.0      ...
# 1477871    90215                4                4.5      ...
# 1477872    95198                4                4.5      ...
# 1477873   102197                4                4.5      ...
# 1477874   102902                3                4.5      ...
# 1477875   106427                4                4.5      ...
# 1477876   114208                4                4.5      ...
# 1477877   124697                3                4.5      ...
# 1477878   127896                4                4.0      ...
# 1477879   129676                4                4.0      ...
# 1477880   138216                3                3.0      ...
# 1477881      803                5                5.0      ...
# 1477882     5491                5                5.0      ...
# 1477883    10236                4                4.0      ...
# 1477884    10813                4                2.5      ...
# 1477885    18028                4                4.0      ...
# 1477886    20189                4                4.0      ...
# 1477887    21710                5                4.0      ...
# 1477888    26335                5                4.0      ...
# 1477889    45616                5                5.0      ...
# 1477890    47277                5                4.0      ...
# 1477891    58623                5                4.0      ...
# 1477892    75519                4                4.5      ...
# 1477893    85813                5                4.5      ...
# 1477894    86260                5                4.5      ...
# 1477895    95453                4                3.0      ...
# 1477896   101385                5                4.5      ...
# 1477897   115253                4                4.0      ...
# 1477898   119849                4                4.0      ...
#
#          srch_query_affinity_score  random_bool  click_bool  \
# 0                        -326.5675            1           0
# 1                        -326.5675            1           0
# 2                        -326.5675            1           0
# 1477882           0.000000           10.000000      -0.250000
# 1477883           0.000000           16.666667       0.250000
# 1477884           0.000000            0.000000       0.000000
# 1477885           0.000000            0.000000      -0.250000
# 1477886          25.000000           25.000000       0.500000
# 1477887           0.000000            0.000000      -1.000000
# 1477888          25.000000           25.000000      -1.000000
# 1477889           0.000000            0.000000       1.000000
# 1477890           0.000000            0.000000      -0.500000
# 1477891           0.000000            0.000000       0.000000
# 1477892           0.000000            0.000000      -0.250000
# 1477893           0.000000           14.285714       0.000000
# 1477894           0.000000            0.000000       0.333333
# 1477895           0.000000            0.000000       0.000000
# 1477896           0.000000            0.000000       0.333333
# 1477897           0.000000            0.000000       0.000000
# 1477898           0.000000            0.000000       0.000000
#
# [1477899 rows x 34 columns]

# %% [markdown]
# ### Modify the dataset for RandomForest regression and other standard ML algorithm

# %%
#Adding Score columns: 5 for booked, 1 clicked and 0 the rest
def assign_score(x):
    if x["booking_bool"]==1:
        val=5
    elif x["click_bool"]==1:
        val=1
    else:
        val=0
    return val
    

train['score'] = train.apply(assign_score , axis=1)

# %%
train
# Out:
#          srch_id            date_time  site_id  visitor_location_country_id  \
# 0             43  2013-01-09 16:45:45        5                          219
# 1             43  2013-01-09 16:45:45        5                          219
# 2             43  2013-01-09 16:45:45        5                          219
# 3             43  2013-01-09 16:45:45        5                          219
# 4             43  2013-01-09 16:45:45        5                          219
# 5             43  2013-01-09 16:45:45        5                          219
# 6             43  2013-01-09 16:45:45        5                          219
# 7             43  2013-01-09 16:45:45        5                          219
# 8             43  2013-01-09 16:45:45        5                          219
# 9             43  2013-01-09 16:45:45        5                          219
# 10            43  2013-01-09 16:45:45        5                          219
# 11            43  2013-01-09 16:45:45        5                          219
# 12            43  2013-01-09 16:45:45        5                          219
# 13            43  2013-01-09 16:45:45        5                          219
# 14            43  2013-01-09 16:45:45        5                          219
# 15            43  2013-01-09 16:45:45        5                          219
# 16            43  2013-01-09 16:45:45        5                          219
# 17            43  2013-01-09 16:45:45        5                          219
# 18            43  2013-01-09 16:45:45        5                          219
# 19            43  2013-01-09 16:45:45        5                          219
# 20            43  2013-01-09 16:45:45        5                          219
# 21            43  2013-01-09 16:45:45        5                          219
# 22            43  2013-01-09 16:45:45        5                          219
# 23            43  2013-01-09 16:45:45        5                          219
# 24            43  2013-01-09 16:45:45        5                          219
# 25            43  2013-01-09 16:45:45        5                          219
# 26            43  2013-01-09 16:45:45        5                          219
# 27            43  2013-01-09 16:45:45        5                          219
# 28            43  2013-01-09 16:45:45        5                          219
# 29            43  2013-01-09 16:45:45        5                          219
# ...          ...                  ...      ...                          ...
# 1477869   332738  2012-12-26 15:56:42       14                          100
# 1477870   332738  2012-12-26 15:56:42       14                          100
# 1477871   332738  2012-12-26 15:56:42       14                          100
# 1477872   332738  2012-12-26 15:56:42       14                          100
# 1477873   332738  2012-12-26 15:56:42       14                          100
# 1477874   332738  2012-12-26 15:56:42       14                          100
# 1477875   332738  2012-12-26 15:56:42       14                          100
# 1477876   332738  2012-12-26 15:56:42       14                          100
# 1477893                      NaN                   NaN              117
# 1477894                      NaN                   NaN              117
# 1477895                      NaN                   NaN              117
# 1477896                      NaN                   NaN              117
# 1477897                      NaN                   NaN              117
# 1477898                      NaN                   NaN              117
#
#          prop_id  prop_starrating  prop_review_score  ...    random_bool  \
# 0           7011                2                2.0  ...              1
# 1           8797                2                2.5  ...              1
# 2          14530                3                5.0  ...              1
# 3          15770                2                2.5  ...              1
# 4          20295                3                4.0  ...              1
# 5          22013                3                3.5  ...              1
# 6          25236                4                3.0  ...              1
# 7          27142                4                4.0  ...              1
# 8          31166                2                3.0  ...              1
# 9          31486                4                4.0  ...              1
# 10         37124                4                4.0  ...              1
# 11         37304                2                3.5  ...              1
# 12         37543                4                3.5  ...              1
# 13         42011                3                3.0  ...              1
# 14         43657                4                4.0  ...              1
# 15         48375                4                3.5  ...              1
# 16         55050                2                3.5  ...              1
# 17         59322                3                3.5  ...              1
# 18         62237                2                3.5  ...              1
# 19         68833                2                3.5  ...              1
# 20         72189                2                3.5  ...              1
# 21         77411                1                3.0  ...              1
# 22         79235                2                3.0  ...              1
# 23         79537                4                4.0  ...              1
# 24         85321                3                4.5  ...              1
# 25         88316                2                3.5  ...              1
# 26         90836                2                2.5  ...              1
# 27         95182                4                4.0  ...              1
# 28        102874                4                4.0  ...              1
# 29        103197                2                3.0  ...              1
# ...          ...              ...                ...  ...            ...
# 1477869    76828                4                4.5  ...              0
# 1477870    85443                3                4.0  ...              0
# 1477871    90215                4                4.5  ...              0
# 1477872    95198                4                4.5  ...              0
# 1477873   102197                4                4.5  ...              0
# 1477874   102902                3                4.5  ...              0
# 1477875   106427                4                4.5  ...              0
# 1477876   114208                4                4.5  ...              0
# 1477877   124697                3                4.5  ...              0
# 1477878   127896                4                4.0  ...              0
# 1477879   129676                4                4.0  ...              0
# 1477880   138216                3                3.0  ...              0
# 1477881      803                5                5.0  ...              0
# 1477882     5491                5                5.0  ...              0
# 1477883    10236                4                4.0  ...              0
# 1477884    10813                4                2.5  ...              0
# 1477885    18028                4                4.0  ...              0
# 1477886    20189                4                4.0  ...              0
# 1477887    21710                5                4.0  ...              0
# 1477888    26335                5                4.0  ...              0
# 1477889    45616                5                5.0  ...              0
# 1477890    47277                5                4.0  ...              0
# 1477891    58623                5                4.0  ...              0
# 1477892    75519                4                4.5  ...              0
# 1477893    85813                5                4.5  ...              0
# 1477894    86260                5                4.5  ...              0
# 1477895    95453                4                3.0  ...              0
# 1477896   101385                5                4.5  ...              0
# 1477897   115253                4                4.0  ...              0
# 1477898   119849                4                4.0  ...              0
#
#          click_bool  gross_bookings_usd  booking_bool  starrating_diff  \
# 0                 0                 NaN             0              6.0
# 1                 0                 NaN             0              6.0
# 2                 0                 NaN             0              6.0
# 3                 0                 NaN             0              6.0
# 4                 0                 NaN             0              6.0
# 5                 0                 NaN             0              6.0
# 6                 0                 NaN             0              6.0
# 7                 0                 NaN             0              6.0
# 8                 0                 NaN             0              6.0
# 9                 0                 NaN             0              6.0
# 10                0                 NaN             0              6.0
# 24            1.1           1.754386            4.093567       0.000000      0
# 25            1.1           0.000000            1.010101       0.000000      0
# 26            1.1           0.000000            0.000000      -1.000000      0
# 27            1.1           1.197605            7.185629       0.000000      0
# 28            1.1           2.985075            9.452736       0.000000      0
# 29            1.1           0.000000            0.000000       0.000000      0
# ...           ...                ...                 ...            ...    ...
# 1477869       1.1           0.000000            0.000000       0.000000      0
# 1477870       1.1           0.000000            0.000000       0.000000      0
# 1477871       1.1           0.000000            6.666667       0.000000      0
# 1477872       1.1           0.000000           12.500000       0.000000      0
# 1477873       1.1           5.882353            5.882353       0.000000      0
# 1477874       1.1           0.000000            0.000000       0.000000      0
# 1477875       1.1           0.000000           16.666667       0.000000      0
# 1477876       1.1           0.000000            0.000000       0.000000      0
# 1477877       1.1           6.666667           13.333333       0.000000      0
# 1477878       1.1           5.882353           11.764706       0.000000      5
# 1477879       1.1           0.000000            5.555556       0.000000      0
# 1477880       1.1           0.000000            0.000000       0.000000      0
# 1477881       1.1           0.000000            0.000000       0.000000      0
# 1477882       1.1           0.000000           10.000000      -0.250000      0
# 1477883       1.1           0.000000           16.666667       0.250000      0
# 1477884       1.1           0.000000            0.000000       0.000000      0
# 1477885       1.1           0.000000            0.000000      -0.250000      0
# 1477886       1.1          25.000000           25.000000       0.500000      5
# 1477887       1.1           0.000000            0.000000      -1.000000      0
# 1477888       1.1          25.000000           25.000000      -1.000000      0
# 1477889       1.1           0.000000            0.000000       1.000000      0
# 1477890       1.1           0.000000            0.000000      -0.500000      0
# 1477891       1.1           0.000000            0.000000       0.000000      0
# 1477892       1.1           0.000000            0.000000      -0.250000      0
# 1477893       1.1           0.000000           14.285714       0.000000      0
# 1477894       1.1           0.000000            0.000000       0.333333      0
# 1477895       1.1           0.000000            0.000000       0.000000      0
# 1477896       1.1           0.000000            0.000000       0.333333      0
# 1477897       1.1           0.000000            0.000000       0.000000      0
# 1477898       1.1           0.000000            0.000000       0.000000      0
#
# [1477899 rows x 35 columns]

# %%
#add month columns and drop some useless columns
train["date_time"] = pd.to_datetime(train["date_time"])
train["month"] = train["date_time"].dt.month
column_id=train["srch_id"]
train = train.drop(["srch_id", "date_time"], axis=1)

# %%
#columns with Nan
train.columns[train.isna().any()].tolist()
# Out:
# ['visitor_hist_starrating', 'visitor_hist_adr_usd', 'gross_bookings_usd']

# %%
#fill Nan
train=train.drop("gross_bookings_usd",axis=1)
values = {'visitor_hist_starrating': 0, 'visitor_hist_adr_usd': 0}
train=train.fillna(value=values)

# %%
np.all(np.isfinite(train))
# Out:
# False

# %%
#there are some infinite values in usd_diff
train= train.replace([np.inf, -np.inf], np.nan)
train.columns[train.isna().any()].tolist()
train=train.fillna(value={"usd_diff":0})

# %%
train.head()
# Out:
#    site_id  visitor_location_country_id  visitor_hist_starrating  \
# 0        5                          219                      0.0
# 1        5                          219                      0.0
# 2        5                          219                      0.0
# 3        5                          219                      0.0
# 4        5                          219                      0.0
#
#    visitor_hist_adr_usd  prop_country_id  prop_id  prop_starrating  \
# 0                   0.0              219     7011                2
# 1                   0.0              219     8797                2
# 2                   0.0              219    14530                3
# 3                   0.0              219    15770                2
# 4                   0.0              219    20295                3
#
#    prop_review_score  prop_brand_bool  prop_location_score1  ...    \
# 0                2.0                1                  2.94  ...
# 1                2.5                1                  2.71  ...
# 2                5.0                1                  1.61  ...
# 3                2.5                1                  2.89  ...
# 4                4.0                1                  3.47  ...
#
#    random_bool  click_bool  booking_bool  starrating_diff  usd_diff  \
# 0            1           0             0              6.0       1.1
# 1            1           0             0              6.0       1.1
# 2            1           0             0              6.0       1.1
# 3            1           0             0              6.0       1.1
# 4            1           0             0              6.0       1.1
#
#    booked_percentage  clicked_percentage  avg_comp_rate  score  month
# 0           0.000000            1.075269           0.00      0      1
# 1           0.000000            0.680272           1.00      0      1
# 2           0.000000            0.000000           0.00      0      1
# 3           0.000000            0.000000           0.00      0      1
# 4           3.488372            5.813953           0.75      0      1
#
# [5 rows x 33 columns]

# %%
np.all(np.isfinite(train))
# Out:
# True

# %% [markdown]
# ### separate labels

# %%
path="C://Users//david\Desktop//VU amsterdam//Data mining"
train = pd.read_csv(path+"/New_train_set.csv")
train.head()
# Out:
#    Unnamed: 0  srch_id  site_id  visitor_location_country_id  \
# 0           0       17       18                          129
# 1           1       17       18                          129
# 2           2       17       18                          129
# 3           3       17       18                          129
# 4           4       17       18                          129
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      3.5                157.19               31     2196
# 1                      3.5                157.19               31     3309
# 2                      3.5                157.19               31    11331
# 3                      3.5                157.19               31    17795
# 4                      3.5                157.19               31    21770
#
#    prop_starrating  prop_review_score  ...    srch_saturday_night_bool  \
# 0                4                4.5  ...                           1
# 1                3                3.5  ...                           1
# 2                4                4.0  ...                           1
# 3                4                4.0  ...                           1
# 4                3                4.5  ...                           1
#
#    srch_query_affinity_score  gross_bookings_usd  starrating_diff  usd_diff  \
# 0                  -326.5675                 NaN              0.5  0.243081
# 1                  -326.5675                 NaN              0.5  0.017477
# 2                  -326.5675                 NaN              0.5  0.289041
# 3                  -326.5675                 NaN              0.5  0.236977
# 4                  -326.5675                 NaN              0.5  0.031230
#
#    booked_percentage  clicked_percentage  avg_comp_rate  month  score
# 0           5.660377            5.660377       0.666667     11      0
# 1           0.000000            6.666667       0.000000     11      0
# 2           5.263158            5.263158       0.000000     11      0
# 3           4.000000            6.000000       1.000000     11      0
# 4           0.000000            7.142857       1.000000     11      0
#
# [5 rows x 33 columns]

# %%
train.columns
# Out:
# Index(['Unnamed: 0', 'srch_id', 'site_id', 'visitor_location_country_id',
#        'visitor_hist_starrating', 'visitor_hist_adr_usd', 'prop_country_id',
#        'prop_id', 'prop_starrating', 'prop_review_score', 'prop_brand_bool',
#        'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'position', 'price_usd', 'promotion_flag',
#        'srch_destination_id', 'srch_length_of_stay', 'srch_booking_window',
#        'srch_adults_count', 'srch_children_count', 'srch_room_count',
#        'srch_saturday_night_bool', 'srch_query_affinity_score',
#        'gross_bookings_usd', 'starrating_diff', 'usd_diff',
#        'booked_percentage', 'clicked_percentage', 'avg_comp_rate', 'month',
#        'score'],
#       dtype='object')

# %%
column_id=train["srch_id"]
train=train.drop(["srch_id","Unnamed: 0", "gross_bookings_usd"], axis=1)

# %%
y=train["score"]
X=train.drop("score", axis=1)

# %%
#X=X.drop("gross_bookings_usd", axis=1)

# %%
X.columns[X.isna().any()].tolist()
# Out:
# []

# %%
np.all(np.isfinite(X))
# Out:
# True

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=13 )

# %%
regr = RandomForestRegressor(random_state=0, n_estimators=30, n_jobs=-1)
rfr = regr.fit(X_train, y_train)
prediction = rfr.predict(X_test)
print(r2_score(prediction, y_test))
# Out:
# -3.033455626943735

# %%
y_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-27d3425f7a85> in <module>()
# ----> 1 y_test
#
# NameError: name 'y_test' is not defined

# %%
prediction_s = pd.Series(prediction)

# %% [markdown]
# ### ElasticNet

# %%
regr = ElasticNet(random_state=0, alpha=5.1506780761681216e-05,l1_ratio=0.4)
y_pred_enet = regr.fit(X_train, y_train).predict(X_test)
r2_score_enet = r2_score(y_test, y_pred_enet)
print("r^2 on test data : %f" % r2_score_enet)
# Out:
# r^2 on test data : 0.103924

# %%
alphas = np.logspace(-5, 1, 60)
enet = ElasticNet(l1_ratio=0.7)
train_errors = list()
test_errors = list()
for alpha in alphas:
    enet.set_params(alpha=alpha)
    enet.fit(X_train, y_train)
    train_errors.append(enet.score(X_train, y_train))
    test_errors.append(enet.score(X_test, y_test))

i_alpha_optim = np.argmax(test_errors)
alpha_optim = alphas[i_alpha_optim]
print("Optimal regularization parameter : %s" % alpha_optim)
# Out:
# Optimal regularization parameter : 5.1506780761681216e-05

# %%
import matplotlib.pyplot as plt
plt.subplot(1, 1, 1)
plt.semilogx(alphas, train_errors, label='Train')
plt.semilogx(alphas, test_errors, label='Test')
plt.vlines(alpha_optim, plt.ylim()[0], np.max(test_errors), color='k',
           linewidth=3, label='Optimum on test')
plt.legend(loc='lower left')
plt.ylim([0, 1.2])
plt.xlabel('Regularization parameter')
plt.ylabel('Performance')
plt.show()

# %%
#import real test set

# %% [markdown]
# ### lambdaMART

# %%
from sklearn.datasets import dump_svmlight_file
from lambdamart import LambdaMART
from random import randint

# %%
#RUND THIS LINE only to save a new file in svm_light format
dump_svmlight_file(X,y,query_id=column_id,zero_based=False, f="C://Users//david\Desktop//VU amsterdam//Data mining"+"/train_forLM_again.txt")

# %%
#tran_LM=pd.read_table("C://Users//david\Desktop//VU amsterdam//Data mining/train_forLM.txt")

# %%
#function to read the svm_light file and split it in TRAIN and TEST
def get_data(file_loc):
    f_train= open("C://Users//david\Desktop//VU amsterdam//Data mining//train_lm.txt","w+")
    f_test= open("C://Users//david\Desktop//VU amsterdam//Data mining//test_lm.txt","w+")
    f = open(file_loc, 'r')
    test_flag=False
    i=1
    previous_id=0
    for line in f:
        arr = line.split()
        ''' Get the score and query id '''
        score = arr[0]
        q_id = arr[1].split(':')[1]
        #print(q_id)
        if previous_id==0:
            f_train.write(line)
        elif previous_id == q_id:
            if test_flag:
                f_test.write(line)
            else:
                f_train.write(line)
        else:
            if i%3 == 0:
                test_flag=True
                f_test.write(line)
            else:
                test_flag=False
                f_train.write(line)
            i+=1
        previous_id=q_id

    f.close()
    f_train.close()
    f_test.close()
# def get_data(file_loc):
# 	f = open(file_loc, 'r')
# 	data = []
# 	for line in f:
# 		new_arr = []
# 		arr = line.split(' #')[0].split()
# 		''' Get the score and query id '''
# 		score = arr[0]
# 		q_id = arr[1].split(':')[1]
# 		new_arr.append(int(score))
# 		new_arr.append(int(q_id))
# 		arr = arr[2:]
# 		''' Extract each feature from the feature vector '''
# 		for el in arr:
# 			new_arr.append(float(el.split(':')[1]))
# 		data.append(new_arr)
# 	f.close()
# 	return np.array(data)

# %%
get_data("C://Users//david\Desktop//VU amsterdam//Data mining/train_forLM_again.txt")

# %%
import pyltr
train_lm=open("C://Users//david\Desktop//VU amsterdam//Data mining//train_lm.txt")
test_lm=open("C://Users//david\Desktop//VU amsterdam//Data mining/test_lm.txt")

#TX, Ty, Tqids, _ = pyltr.data.letor.read_dataset(train_lm)
Train_features, Train_scores, Train_qids, _ = pyltr.data.letor.read_dataset(train_lm)
Test_features, Test_scores, Test_qids, _ = pyltr.data.letor.read_dataset(test_lm)

# %%
metric = pyltr.metrics.NDCG(k=10)
model = pyltr.models.LambdaMART(
    metric=metric,
    n_estimators=50,
    learning_rate=0.07,
    max_features=0.5,
    query_subsample=0.5,
    max_leaf_nodes=10,
    min_samples_leaf=64,
    verbose=1,
)

# %%
#TRAIN
model.fit(Train_features, Train_scores, Train_qids)
# Out:
#  Iter  Train score  OOB Improve    Remaining                           Monitor Output
#     1       0.3768       0.3355       37.68m
#     2       0.4310       0.0530       36.80m
#     3       0.4817       0.0491       36.26m
#     4       0.5068       0.0265       35.57m
#     5       0.5141       0.0100       35.09m
#     6       0.5192       0.0029       34.49m
#     7       0.5248       0.0049       34.04m
#     8       0.5310       0.0067       33.21m
#     9       0.5381       0.0016       32.56m
#    10       0.5394       0.0030       32.14m
#    15       0.5469       0.0013       30.08m
#    20       0.5505       0.0013       26.60m
#    25       0.5562       0.0006       23.37m
#    30       0.5597       0.0006       18.94m
#    35       0.5632       0.0006       14.18m
#    40       0.5685       0.0002        9.67m
#    45       0.5673       0.0005        4.93m
#    50       0.5681       0.0005        0.00s

# %%
Epred = model.predict(Test_features)
print ('Random ranking:', metric.calc_mean_random(Test_qids, Test_scores))
print ('Our model:', metric.calc_mean(Test_qids, Test_scores, Epred))
# Out:
# Random ranking: 0.22850953539318647
# Our model: 0.5693170665457322

# %% [markdown]
# #### Extracting data from train (percentage book/click) and store it

# %%
path="C://Users//david\Desktop//VU amsterdam//Data mining"
train = pd.read_csv(path+"/training_set_VU_DM.csv")
train.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score      ...       comp6_rate_percent_diff  \
# 0                3                3.5      ...                           NaN
# 1                4                4.0      ...                           NaN
# 2                3                4.5      ...                           NaN
# 3                2                4.0      ...                           NaN
# 4                4                3.5      ...                           NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff  click_bool  gross_bookings_usd  booking_bool
# 0                      NaN           0                 NaN             0
# 1                      NaN           0                 NaN             0
# 2                      NaN           0                 NaN             0
# 3                      5.0           0                 NaN             0
# 4                      NaN           0                 NaN             0
#
# [5 rows x 54 columns]

# %%
hotel_quality = pd.DataFrame(train.prop_id.value_counts(dropna = False))
hotel_quality = hotel_quality.join(pd.DataFrame(train.prop_id[train.booking_bool == 1].value_counts().astype(int)), rsuffix = "book")
hotel_quality = hotel_quality.join(pd.DataFrame(train.prop_id[train.click_bool == 1].value_counts().astype(int)), rsuffix = "click")
hotel_quality.columns = ["counts", "booked", "clicked"]
hotel_quality["booked_percentage"] = hotel_quality.booked / hotel_quality.counts * 100
hotel_quality["clicked_percentage"] = hotel_quality.clicked / hotel_quality.counts * 100

# %%
hotel_quality = hotel_quality.fillna(value = {"booked_percentage": 0, "clicked_percentage": 0})

# %%
hotel_quality=hotel_quality.drop(["counts", "booked", "clicked"], axis=1)

# %%
hotel_quality.to_csv(path+"/hotel_quality.csv")

# %%
hotel_quality.max()

# %% [markdown]
# ### test on the test dataset to insert hotels_train quality

# %%
#load test set
test = pd.read_csv(path+"/test_set_VU_DM.csv")
test.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-02-02 15:27:40       24                          216
# 1        1  2013-02-02 15:27:40       24                          216
# 2        1  2013-02-02 15:27:40       24                          216
# 3        1  2013-02-02 15:27:40       24                          216
# 4        1  2013-02-02 15:27:40       24                          216
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219     3180
# 1                      NaN                   NaN              219     5543
# 2                      NaN                   NaN              219    14142
# 3                      NaN                   NaN              219    22393
# 4                      NaN                   NaN              219    24194
#
#    prop_starrating  prop_review_score           ...             \
# 0                3                4.5           ...
# 1                3                4.5           ...
# 2                2                3.5           ...
# 3                3                4.5           ...
# 4                3                4.5           ...
#
#    comp5_rate_percent_diff  comp6_rate  comp6_inv  comp6_rate_percent_diff  \
# 0                      NaN         NaN        NaN                      NaN
# 1                      NaN         NaN        NaN                      NaN
# 2                     10.0         NaN        NaN                      NaN
# 3                      NaN         NaN        NaN                      NaN
# 4                      NaN         NaN        NaN                      NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         NaN        NaN
# 1         NaN        NaN                      NaN         NaN        NaN
# 2         NaN        NaN                      NaN         NaN        NaN
# 3         NaN        NaN                      NaN         NaN        NaN
# 4         NaN        NaN                      NaN         NaN        NaN
#
#    comp8_rate_percent_diff
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
# [5 rows x 50 columns]

# %%
hotels_train = pd.read_csv(path+"//hotel_quality.csv")
hotels_train.columns=["prop_id", "booked_perc", "clicked_perc"]

# %%
new_data_test = test.join(hotels_train.set_index("prop_id"),how="left", on="prop_id")

# %% [markdown]
# ### How many hotels are in test but not in train? -> 121665 out of 129438

# %%
hotel_quality_test.index
# Out:
# Int64Index([104517, 124342,  68420, 134154,  59781,  40279, 137997,  60846,
#             116942,  49656,
#             ...
#              88165,   2915,  99234, 122755,  41332,   6221,  15205,  29038,
#              24940,  82669],
#            dtype='int64', length=129438)

# %%
hotel_quality_test.index.intersection(hotel_quality.index)
# Out:
# Int64Index([104517, 124342,  68420, 134154,  59781,  40279, 137997,  60846,
#             116942,  49656,
#             ...
#             133923,  76615,  93007,  62348,  77677,  88165,  99234,  41332,
#              29038,  24940],
#            dtype='int64', length=121665)

# %% [markdown]
# ### Test on real test set

# %%
path="C://Users//david\Desktop//VU amsterdam//Data mining"
new_test_set = pd.read_csv(path+"/New_test_set.csv")
new_test_set.head()
# Out:
#    Unnamed: 0  srch_id  site_id  visitor_location_country_id  \
# 0           0        1       24                          216
# 1           1        1       24                          216
# 2           2        1       24                          216
# 3           3        1       24                          216
# 4           4        1       24                          216
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                     3.43                151.39              219     3180
# 1                     3.43                151.39              219     5543
# 2                     3.43                151.39              219    14142
# 3                     3.43                151.39              219    22393
# 4                     3.43                151.39              219    24194
#
#    prop_starrating  prop_review_score  ...    srch_room_count  \
# 0                3                4.5  ...                  1
# 1                3                4.5  ...                  1
# 2                2                3.5  ...                  1
# 3                3                4.5  ...                  1
# 4                3                4.5  ...                  1
#
#    srch_saturday_night_bool  srch_query_affinity_score  random_bool  \
# 0                         0                  -326.5675            0
# 1                         0                  -326.5675            0
# 2                         0                  -326.5675            0
# 3                         0                  -326.5675            0
# 4                         0                  -326.5675            0
#
#    starrating_diff  usd_diff  booked_perc  clicked_perc  avg_comp_rate  month
# 0             0.43  0.104550     4.301075      4.301075            0.0    2.0
# 1             0.43  0.108215     5.327869      6.147541            0.0    2.0
# 2             1.43  0.489901     1.342282      2.684564            0.5    2.0
# 3             0.43  0.024761     1.379310      1.379310            0.0    2.0
# 4             0.43  0.282470     1.463415      1.951220            0.0    2.0
#
# [5 rows x 31 columns]

# %%
new_test_set = new_test_set.fillna(value = {"booked_perc": 2.89, "clicked_perc": 5.01})
new_test_set = new_test_set.drop("Unnamed: 0", axis=1)
# Out:
#          srch_id  site_id  visitor_location_country_id  \
# 0              1       24                          216
# 1              1       24                          216
# 2              1       24                          216
# 3              1       24                          216
# 4              1       24                          216
# 5              1       24                          216
# 6              1       24                          216
# 1900608                     3.43                151.39              219
# 1900609                     3.43                151.39              141
# 1900610                     3.43                151.39              141
# 1900611                     3.43                151.39              141
# 1900612                     3.43                151.39              141
# 1900613                     3.43                151.39              141
# 1900614                     3.43                151.39              141
# 1900615                     3.43                151.39              219
# 1900616                     3.43                151.39              219
#
#          prop_id  prop_starrating  prop_review_score  prop_brand_bool  ...    \
# 0           3180                3                4.5                1  ...
# 1           5543                3                4.5                1  ...
# 2          14142                2                3.5                1  ...
# 3          22393                3                4.5                1  ...
# 4          24194                3                4.5                1  ...
# 5          28181                3                4.5                1  ...
# 6          34263                3                4.5                1  ...
# 7          37567                2                4.5                0  ...
# 8          50162                2                3.5                1  ...
# 9          54937                3                4.0                1  ...
# 10         56050                3                4.0                1  ...
# 11         61632                0                0.0                0  ...
# 12         61934                3                4.5                1  ...
# 13         63894                3                4.5                1  ...
# 14         72090                3                4.0                1  ...
# 15         73666                3                4.5                1  ...
# 16         74045                3                4.0                1  ...
# 17         78599                4                4.5                1  ...
# 18         82231                3                4.5                1  ...
# 19         89466                2                3.0                0  ...
# 20         90385                3                4.5                1  ...
# 21         94729                3                4.5                1  ...
# 22         95031                3                3.5                1  ...
# 23         99484                3                4.0                1  ...
# 24        123675                3                4.5                1  ...
# 25        128085                2                3.0                1  ...
# 26        128871                2                3.0                1  ...
# 27        134992                2                5.0                1  ...
# 28        139162                3                4.5                1  ...
# 29          6533                4                4.0                1  ...
# ...          ...              ...                ...              ...  ...
# 1900587    41743                3                5.0                1  ...
# 1900588    43642                2                3.0                0  ...
# 1900589    46867                2                3.5                0  ...
# 1900590    49249                3                4.0                1  ...
# 1900591    50878                2                4.5                0  ...
# 1900592    51401                3                4.0                1  ...
# 1900593    51990                3                3.5                1  ...
# 1900594    52806                2                3.5                0  ...
# 1900595    55079                2                3.0                1  ...
# 1900596    55473                3                3.0                0  ...
# 1900597    64428                4                4.0                1  ...
# 1900598    68053                0                2.5                1  ...
# 1900599    74089                3                4.5                1  ...
# 1900600    89332                0                0.0                0  ...
# 1900601    92285                0                4.5                0  ...
# 1900602   101514                3                3.0                0  ...
# 1900603   110240                0                4.5                1  ...
# 1900604   125109                2                3.0                1  ...
# 1900605   127223                0                5.0                0  ...
# 1900606   130744                3                4.0                1  ...
# 1900607   135523                3                5.0                1  ...
# 1900608   135672                3                3.5                0  ...
# 1900609    22822                4                5.0                1  ...
# 1900610    32684                3                0.0                1  ...
# 1900611    55984                5                0.0                1  ...
# 1900612    63908                2                4.0                0  ...
# 1900613    93971                4                0.0                1  ...
# 1900614    98168                3                0.0                0  ...
# 1900615      464                3                4.5                1  ...
# 1900616     1461                2                3.5                1  ...
#
#          srch_room_count  srch_saturday_night_bool  srch_query_affinity_score  \
# 0                      1                         0                  -326.5675
# 1                      1                         0                  -326.5675
# 2                      1                         0                  -326.5675
# 3                      1                         0                  -326.5675
# 4                      1                         0                  -326.5675
# 5                      1                         0                  -326.5675
# 6                      1                         0                  -326.5675
# 7                      1                         0                  -326.5675
# 8                      1                         0                  -326.5675
# 1900594            0.0    1.0
# 1900595            0.0    1.0
# 1900596            0.0    1.0
# 1900597            0.0    1.0
# 1900598            0.0    1.0
# 1900599            0.0    1.0
# 1900600            0.0    1.0
# 1900601            0.0    1.0
# 1900602            0.0    1.0
# 1900603            0.0    1.0
# 1900604            0.0    1.0
# 1900605            0.0    1.0
# 1900606            0.0    1.0
# 1900607            0.0    1.0
# 1900608            0.0    1.0
# 1900609            0.0    3.0
# 1900610            0.0    3.0
# 1900611            0.0    3.0
# 1900612            0.0    3.0
# 1900613            0.0    3.0
# 1900614            0.0    3.0
# 1900615            0.0    4.0
# 1900616            NaN    NaN
#
# [1900617 rows x 30 columns]

# %%
new_test_set = new_test_set.drop("random_bool", axis=1)
new_test_set.columns
# Out:
# Index(['srch_id', 'site_id', 'visitor_location_country_id',
#        'visitor_hist_starrating', 'visitor_hist_adr_usd', 'prop_country_id',
#        'prop_id', 'prop_starrating', 'prop_review_score', 'prop_brand_bool',
#        'prop_location_score1', 'prop_location_score2',
#        'prop_log_historical_price', 'price_usd', 'promotion_flag',
#        'srch_destination_id', 'srch_length_of_stay', 'srch_booking_window',
#        'srch_adults_count', 'srch_children_count', 'srch_room_count',
#        'srch_saturday_night_bool', 'srch_query_affinity_score',
#        'starrating_diff', 'usd_diff', 'booked_perc', 'clicked_perc',
#        'avg_comp_rate', 'month'],
#       dtype='object')

# %%
column_id=new_test_set["srch_id"]
X=new_test_set.drop("srch_id", axis=1)

# %%
y = [randint(0, 5) for p in range(0, 1900617)]

# %%
X.columns[X.isna().any()].tolist()
# Out:
# ['avg_comp_rate', 'month']

# %%
#np.all(np.isfinite(X))
#X= X.replace([np.inf, -np.inf], np.nan)
X = X.fillna(value = {"month": 1,"avg_comp_rate": 0}) 
X.columns[X.isna().any()].tolist()
# Out:
# []

# %%
X= X.replace(-np.Inf, np.nan)
np.all(np.isfinite(X))
# Out:
# False

# %%
dump_svmlight_file(X,y,query_id=column_id,zero_based=False, f="C://Users//david\Desktop//VU amsterdam//Data mining//Preprocessed_test_set.txt")

# %%
real_test_lm=open("C://Users//david\Desktop//VU amsterdam//Data mining/Preprocessed_test_set.txt")
Test_features_r, Test_scores_r, Test_qids_r, _ = pyltr.data.letor.read_dataset(real_test_lm)

# %%
#Test_features_r
# Out:
# array([[ 24.        , 216.        ,   3.43      , ...,   4.30107527,
#           0.        ,   2.        ],
#        [ 24.        , 216.        ,   3.43      , ...,   6.14754098,
#           0.        ,   2.        ],
#        [ 24.        , 216.        ,   3.43      , ...,   2.68456376,
#           0.5       ,   2.        ],
#        ...,
#        [ 16.        ,  31.        ,   3.43      , ...,   5.01      ,
#           0.        ,   3.        ],
#        [  5.        , 219.        ,   3.43      , ...,   7.75193798,
#           0.        ,   4.        ],
#        [  5.        , 219.        ,   3.43      , ...,   5.01      ,
#           0.        ,   1.        ]])

# %%
# PREDICT REAL DEAL
Epred_r = model.predict(Test_features_r)

# %%
Epred_r
# Out:
# array([-2.36017838, -2.19571392, -2.46626943, ..., -2.25261225,
#        -2.02981547, -2.297421  ])
